# %%
import math

x1, y1, x2, y2, x3, y3 = eval(input("Enter three points: "))

a = math.sqrt((x2 - x3)**2 + (y2 - y3)**2)
b = math.sqrt((x1 - x3)**2 + (y1 - y3)**2)
c = math.sqrt((x1 - x2)**2 + (y1 - y2)**2)

A_rad = math.acos((a * a - b * b - c * c) / (-2 * b * c))
B_rad = math.acos((b * b - a * a - c * c) / (-2 * a * c))
C_rad = math.acos((c * c - b * b - a * a) / (-2 * a * b))

A = math.degrees(A_rad)
B = math.degrees(B_rad)
C = math.degrees(C_rad)

print(f"The three angles, A, B, C are {round(A, 2)} {round(B, 2)} {round(C, 2)}")
# Out:
# The three angles, A, B, C are 45.0 90.0 45.0

# %%
import math

Radius = 6371.01

x1, y1 = eval(input("Enter point 1 (latitude and longitude) in degrees: "))
x2, y2 = eval(input("Enter point 2 (latitude and longitude) in degrees: "))

x1_rad = math.radians(x1)
y1_rad = math.radians(y1)
x2_rad = math.radians(x2)
y2_rad = math.radians(y2)

d = Radius * math.acos(
    math.sin(x1_rad) * math.sin(x2_rad) + 
    math.cos(x1_rad) * math.cos(x2_rad) * math.cos(y1_rad - y2_rad)
)

print(f"The distance between the two points is {d} km")
# Out:
# The distance between the two points is 2104.174251198839 km

# %%
s1 = 'roast beef'
s2 = 'ham'
s3 = 'head'
s4 = 'clam'

Poem_Template = """My kitty cat likes %s,
My kitty cat likes %s,
My kitty cat likes %s
And now thinks he's a %s."""

Result = Poem_Template % (s1, s2, s3, s4)

print(Result)
# Out:
# My kitty cat likes roast beef,
# My kitty cat likes ham,
# My kitty cat likes head
# And now thinks he's a clam.

# %%
salutation = "Mr."
name = "John Doe"
product = "super toaster"
verbed = "exploded"
room = "kitchen"
animals = "hungry tigers"
amount = "$50.00"
percent = 99.9
spokesman = "Jane Smith"
job_title = "Customer Service Manager"

letter = """Dear {salutation} {name},

Thank you for your letter. We are sorry that our {product}
{verbed} in your {room}. Please note that it should never
be used in a {room}, especially near any {animals}.

Send us your receipt and {amount} for shipping and handling.
We will send you another {product} that, in our tests,
is {percent}% less likely to have {verbed}.

Thank you for your support.

Sincerely,
{spokesman}
{job_title}"""

print(letter.format(
    salutation=salutation, 
    name=name, 
    product=product, 
    verbed=verbed, 
    room=room, 
    animals=animals, 
    amount=amount, 
    percent=percent, 
    spokesman=spokesman, 
    job_title=job_title
))
# Out:
# Dear Mr. John Doe,
#
# Thank you for your letter. We are sorry that our super toaster
# exploded in your kitchen. Please note that it should never
# be used in a kitchen, especially near any hungry tigers.
#
# Send us your receipt and $50.00 for shipping and handling.
# We will send you another super toaster that, in our tests,
# is 99.9% less likely to have exploded.
#
# Thank you for your support.
#
# Sincerely,
# Jane Smith
# Customer Service Manager

# %%
song = """When an eel grabs your arm,
And it causes great harm,
That's - a moray!"""

words = song.split()
new_words = []

for word in words:
    if word.startswith('m'):
        new_words.append(word.capitalize())
    else:
        new_words.append(word)

print(" ".join(new_words))
# Out:
# When an eel grabs your arm, And it causes great harm, That's - a Moray!

# %%
with open('hw2_6_input.txt', 'r', encoding='utf-8') as file:
    content = file.read()
    s = content.split('"')[1]

raw_list = s.split(',')

clean_list = [fruit.strip() for fruit in raw_list]

result = "-".join(clean_list)

print(result)
# Out:
# 蘋果-香蕉-鳳梨-水蜜桃

# %%
password = input("Enter password: ")

length_valid = 7 <= len(password) <= 12

is_valid = length_valid and password[0].isupper() and not password.isupper()

if len(password) >= 3:
    masked_password = password[:2] + "*" + password[-1]
else:
    masked_password = password

print(f"{password=}")
print(f"Is valid: {is_valid}")
print(f"Masked: {masked_password}")
# Out:
# password='secret123'
# Is valid: False
# Masked: se*3
